# %%
from openai import OpenAI
import pandas as pd

client = OpenAI(api_key=#Addyourapikey)

#Get the embedding vectors from OAI API
def fetch_oai_embeddings(input_strings:list,
                         embedding_model: str,
                         oai_client:OpenAI)-> list:
    """
    Get the embedding vectors from the OpenAI API.

    This function takes a list of text inputs and retrieves their corresponding
    embedding vectors using the specified OpenAI embedding model. The function
    returns a list of embedding vectors.

    Parameters:
    -----------
    input_strings : list
        A list of text strings for which to generate embeddings.
    embedding_model : str
        The name of the OpenAI embedding model to use (e.g., "text-embedding-3-small").
    oai_client : OpenAI
        An authenticated OpenAI client instance.

    Returns:
    --------
    list
        A list of embedding vectors, where each vector corresponds to an input string.

    Example:
    --------
    client = OpenAI(api_key="your_api_key")
    >>> texts = [
    ...     'I love embeddings, they make so much sense',
    ...     'Embeddings are useful for various applications',
    ...     'Understanding embeddings can enhance machine learning models'
    ... ]
    >>> embeddings = fetch_oai_embeddings(texts, "text-embedding-3-small", client)
    >>> print(embeddings)
    """
    
    responses = []

    #Get the embedding values for each input in your list
    #Probably a way to do this async
    for input_string in input_strings:
        response = oai_client.embeddings.create(
            input=input_string,
            model=embedding_model)
        responses.append(response.data[0].embedding)

    return responses

# %%
text = [
    'I love embeddings, they make so much sense',
    'Embeddings are useful for various applications',
    'Understanding embeddings can enhance machine learning models'
]

test_embs = fetch_oai_embeddings(text, 
                     "text-embedding-3-small", 
                     client)

# %%
import pandas as pd

df = pd.read_csv('/Users/adamfletcher/Desktop/JA_PP - Test Set_220524.csv')

df.head()
# Out:
#                                           Unnamed: 0  \
# 0  Facebook20231116140000-1898https://slguardian....
# 1  Marawa Research and Exploration20231116104500-...
# 2  Rio Tinto20231116104500-493https://www.mining....
# 3  Blue Minerals Jamaica20231116104500-493https:/...
# 4  Metals Co20231116104500-493https://www.mining....
#
#                       organization        gkg_record_id  \
# 0                         Facebook  20231116140000-1898
# 1  Marawa Research and Exploration   20231116104500-493
# 2                        Rio Tinto   20231116104500-493
# 3            Blue Minerals Jamaica   20231116104500-493
# 4                        Metals Co   20231116104500-493
#
#                                  document_identifier company_sentiment  \
# 0  https://slguardian.org/afghanistan-collapse-of...           neutral
# 1  https://www.mining.com/web/the-promise-and-ris...          negative
# 2  https://www.mining.com/web/the-promise-and-ris...          negative
# 3  https://www.mining.com/web/the-promise-and-ris...          negative
# 4  https://www.mining.com/web/the-promise-and-ris...          negative
#
#   article_sentiment company_relevance
# 0     very negative         very weak
# 1          negative              weak
# 2          negative              weak
# 3          negative              weak
# 4          negative              weak

# %%
def trim_text_to_600_words(text: str) -> str:
    """
    Reads the text from a specified file and trims it to the first 600 words if it exceeds that length.
    
    This function is particularly useful when working with models like the OpenAI embedding model, which have a 
    maximum token input limit. Since the average word length in English roughly corresponds to 0.75 tokens, 
    limiting the text to 600 words helps ensure that the token count remains within the model's acceptable range.

    Parameters:
    - file_path (str): The path to the text file to be read.

    Returns:
    - str: The trimmed text containing up to 600 words.
    
    Example:
    >>> trimmed_text = trim_text_to_600_words(text)
    >>> print(trimmed_text)
    """
    # Split the text into words
    words = text.split()
    
    # Check if the number of words is more than 600
    if len(words) > 600:
        # Trim the list of words to the first 600 words
        words = words[:600]
    
    # Join the words back into a string
    trimmed_text = ' '.join(words)
    
    return trimmed_text

# %%
import os

df_embs = pd.DataFrame(columns=['gkg_record_id', 'oai_embeddings'])

for doc_id in df['gkg_record_id'].unique():
    # print(doc_id)
    if doc_id == 'nan':
        continue
    elif type(doc_id) == float:
        continue 
    
    doc_id_filename = doc_id + ".txt"
    file_path = f"/Users/adamfletcher/Desktop/article_text/{doc_id_filename}"
    if not os.path.exists(file_path):
        print(f"{file_path} not found")
    else: 
        with open(file_path) as f:
            content = f.read()
        
        content = trim_text_to_600_words(content)
        embs = fetch_oai_embeddings([content], 
                                    "text-embedding-3-small", 
                                    client)
        df_embs = pd.concat([df_embs, pd.DataFrame({'gkg_record_id': doc_id, 'oai_embeddings': embs})])
# Out:
# Empty DataFrame
# Columns: [gkg_record_id, oai_embeddings]
# Index: []
# /Users/adamfletcher/Desktop/article_text/20231101230000-1352.txt not found
# /Users/adamfletcher/Desktop/article_text/20231108194500-2193.txt not found
# /Users/adamfletcher/Desktop/article_text/20230926160000-926.txt not found
# /Users/adamfletcher/Desktop/article_text/20150321104500-913.txt not found
# /Users/adamfletcher/Desktop/article_text/20170905171500-999.txt not found
# /Users/adamfletcher/Desktop/article_text/20171115103000-T60.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128191500-2296.txt not found
# /Users/adamfletcher/Desktop/article_text/20200924150000-T1243.txt not found
# /Users/adamfletcher/Desktop/article_text/20191118090000-788.txt not found
# /Users/adamfletcher/Desktop/article_text/20161130053000-T2477.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128204500-2558.txt not found
# /Users/adamfletcher/Desktop/article_text/20221207001500-429.txt not found
# /Users/adamfletcher/Desktop/article_text/20160525074500-1453.txt not found
# /Users/adamfletcher/Desktop/article_text/20221207200000-216.txt not found
# /Users/adamfletcher/Desktop/article_text/20190916033000-1051.txt not found
# /Users/adamfletcher/Desktop/article_text/20150702011500-1656.txt not found
# /Users/adamfletcher/Desktop/article_text/20180613070000-572.txt not found
# /Users/adamfletcher/Desktop/article_text/20160119053000-969.txt not found
# /Users/adamfletcher/Desktop/article_text/20170306083000-1974.txt not found
# /Users/adamfletcher/Desktop/article_text/20161130013000-2842.txt not found
# /Users/adamfletcher/Desktop/article_text/20161130031500-T2592.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128201500-2774.txt not found
# /Users/adamfletcher/Desktop/article_text/20200930154500-1300.txt not found
# /Users/adamfletcher/Desktop/article_text/20201121194500-285.txt not found
# /Users/adamfletcher/Desktop/article_text/20201118071500-297.txt not found
# /Users/adamfletcher/Desktop/article_text/20221207101500-284.txt not found
# /Users/adamfletcher/Desktop/article_text/20221115171500-321.txt not found
# /Users/adamfletcher/Desktop/article_text/20160525233000-440.txt not found
# /Users/adamfletcher/Desktop/article_text/20160119224500-348.txt not found
# /Users/adamfletcher/Desktop/article_text/20160525034500-1963.txt not found
# /Users/adamfletcher/Desktop/article_text/20171103143000-129.txt not found
# /Users/adamfletcher/Desktop/article_text/20160225234500-294.txt not found
# /Users/adamfletcher/Desktop/article_text/20170325121500-234.txt not found
# /Users/adamfletcher/Desktop/article_text/20221123000000-768.txt not found
# /Users/adamfletcher/Desktop/article_text/20210505114500-446.txt not found
# /Users/adamfletcher/Desktop/article_text/20191219193000-1266.txt not found
# /Users/adamfletcher/Desktop/article_text/20221114203000-1637.txt not found
# /Users/adamfletcher/Desktop/article_text/20160525051500-2455.txt not found
# /Users/adamfletcher/Desktop/article_text/20221207091500-732.txt not found
# /Users/adamfletcher/Desktop/article_text/20180511113000-1807.txt not found
# /Users/adamfletcher/Desktop/article_text/20171115150000-310.txt not found
# /Users/adamfletcher/Desktop/article_text/20160607191500-2752.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128191500-2034.txt not found
# /Users/adamfletcher/Desktop/article_text/20221207213000-250.txt not found
# /Users/adamfletcher/Desktop/article_text/20171031203000-T296.txt not found
# /Users/adamfletcher/Desktop/article_text/20180706234500-1703.txt not found
# /Users/adamfletcher/Desktop/article_text/20191218191500-188.txt not found
# /Users/adamfletcher/Desktop/article_text/20151103194500-1179.txt not found
# /Users/adamfletcher/Desktop/article_text/20220203100000-1059.txt not found
# /Users/adamfletcher/Desktop/article_text/20150907094500-289.txt not found
# /Users/adamfletcher/Desktop/article_text/20221116180000-1290.txt not found
# /Users/adamfletcher/Desktop/article_text/20221207030000-184.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128191500-434.txt not found
# /Users/adamfletcher/Desktop/article_text/20150509183000-1032.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128183000-1821.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128190000-2298.txt not found
# /Users/adamfletcher/Desktop/article_text/20180606133000-1884.txt not found
# /Users/adamfletcher/Desktop/article_text/20200826231500-924.txt not found
# /Users/adamfletcher/Desktop/article_text/20160525061500-2619.txt not found
# /Users/adamfletcher/Desktop/article_text/20220331084500-T45.txt not found
# /Users/adamfletcher/Desktop/article_text/20221123181500-1324.txt not found
# /Users/adamfletcher/Desktop/article_text/20171115083000-T2218.txt not found
# /Users/adamfletcher/Desktop/article_text/20201125064500-478.txt not found
# /Users/adamfletcher/Desktop/article_text/20201229173000-T861.txt not found
# /Users/adamfletcher/Desktop/article_text/20160210000000-38.txt not found
# /Users/adamfletcher/Desktop/article_text/20171106194500-2539.txt not found
# /Users/adamfletcher/Desktop/article_text/20220209200000-945.txt not found
# /Users/adamfletcher/Desktop/article_text/20201118061500-414.txt not found
# /Users/adamfletcher/Desktop/article_text/20180922020000-1780.txt not found
# /Users/adamfletcher/Desktop/article_text/20200309203000-2525.txt not found
# /Users/adamfletcher/Desktop/article_text/20191217223000-2213.txt not found
# /Users/adamfletcher/Desktop/article_text/20181012083000-T2226.txt not found
# /Users/adamfletcher/Desktop/article_text/20180618184500-908.txt not found
# /Users/adamfletcher/Desktop/article_text/20191218071500-1304.txt not found
# /Users/adamfletcher/Desktop/article_text/20170322210000-T754.txt not found
# /Users/adamfletcher/Desktop/article_text/20201002114500-T1098.txt not found
# /Users/adamfletcher/Desktop/article_text/20170918051500-T1497.txt not found
# /Users/adamfletcher/Desktop/article_text/20161214143000-375.txt not found
# /Users/adamfletcher/Desktop/article_text/20180206153000-2120.txt not found
# /Users/adamfletcher/Desktop/article_text/20180212121500-224.txt not found
# /Users/adamfletcher/Desktop/article_text/20220321204500-223.txt not found
# /Users/adamfletcher/Desktop/article_text/20190623234500-1064.txt not found
# /Users/adamfletcher/Desktop/article_text/20210323231500-1731.txt not found
# /Users/adamfletcher/Desktop/article_text/20200817231500-1512.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128031500-1027.txt not found
# /Users/adamfletcher/Desktop/article_text/20170611144500-T1092.txt not found
# /Users/adamfletcher/Desktop/article_text/20160209101500-2334.txt not found
# /Users/adamfletcher/Desktop/article_text/20160209073000-2108.txt not found
# /Users/adamfletcher/Desktop/article_text/20200703200000-660.txt not found
# /Users/adamfletcher/Desktop/article_text/20151118183000-765.txt not found
# /Users/adamfletcher/Desktop/article_text/20190319081500-438.txt not found
# /Users/adamfletcher/Desktop/article_text/20150313143000-1893.txt not found
# /Users/adamfletcher/Desktop/article_text/20191127224500-503.txt not found
# /Users/adamfletcher/Desktop/article_text/20210614031500-T631.txt not found
# /Users/adamfletcher/Desktop/article_text/20221019154500-996.txt not found
# /Users/adamfletcher/Desktop/article_text/20201118061500-1372.txt not found
# /Users/adamfletcher/Desktop/article_text/20190524233000-T1548.txt not found
# /Users/adamfletcher/Desktop/article_text/20200503083000-T21.txt not found
# /Users/adamfletcher/Desktop/article_text/20161130064500-1342.txt not found
# /Users/adamfletcher/Desktop/article_text/20200323033000-852.txt not found
# /Users/adamfletcher/Desktop/article_text/20220404011500-679.txt not found
# /Users/adamfletcher/Desktop/article_text/20180622100000-985.txt not found
# /Users/adamfletcher/Desktop/article_text/20160205094500-2331.txt not found
# /Users/adamfletcher/Desktop/article_text/20200803163000-1121.txt not found
# /Users/adamfletcher/Desktop/article_text/20170428031500-2524.txt not found
# /Users/adamfletcher/Desktop/article_text/20190519000000-991.txt not found
# /Users/adamfletcher/Desktop/article_text/20180828061500-T1551.txt not found
# /Users/adamfletcher/Desktop/article_text/20201118110000-1599.txt not found
# /Users/adamfletcher/Desktop/article_text/20160828210000-791.txt not found
# /Users/adamfletcher/Desktop/article_text/20190815223000-2122.txt not found
# /Users/adamfletcher/Desktop/article_text/20200706181500-39.txt not found
# /Users/adamfletcher/Desktop/article_text/20161025043000-983.txt not found
# /Users/adamfletcher/Desktop/article_text/20191105001500-577.txt not found
# /Users/adamfletcher/Desktop/article_text/20211213144500-637.txt not found
# /Users/adamfletcher/Desktop/article_text/20210613050000-62.txt not found
# /Users/adamfletcher/Desktop/article_text/20160209094500-1660.txt not found
# /Users/adamfletcher/Desktop/article_text/20220923030000-T286.txt not found
# /Users/adamfletcher/Desktop/article_text/20161025181500-1541.txt not found
# /Users/adamfletcher/Desktop/article_text/20221113084500-263.txt not found
# /Users/adamfletcher/Desktop/article_text/20160119103000-2367.txt not found
# /Users/adamfletcher/Desktop/article_text/20180622040000-861.txt not found
# /Users/adamfletcher/Desktop/article_text/20170530224500-646.txt not found
# /Users/adamfletcher/Desktop/article_text/20200712063000-3.txt not found
# /Users/adamfletcher/Desktop/article_text/20190621110000-T2220.txt not found
# /Users/adamfletcher/Desktop/article_text/20180709173000-311.txt not found
# /Users/adamfletcher/Desktop/article_text/20160210003000-1145.txt not found
# /Users/adamfletcher/Desktop/article_text/20150806020000-1427.txt not found
# /Users/adamfletcher/Desktop/article_text/20160822214500-918.txt not found
# /Users/adamfletcher/Desktop/article_text/20161202103000-2762.txt not found
# /Users/adamfletcher/Desktop/article_text/20200930214500-1989.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128193000-282.txt not found
# /Users/adamfletcher/Desktop/article_text/20201118061500-309.txt not found
# /Users/adamfletcher/Desktop/article_text/20170429101500-T2163.txt not found
# /Users/adamfletcher/Desktop/article_text/20161130024500-2227.txt not found
# /Users/adamfletcher/Desktop/article_text/20180725171500-1668.txt not found
# /Users/adamfletcher/Desktop/article_text/20161210054500-1182.txt not found
# /Users/adamfletcher/Desktop/article_text/20190320034500-1262.txt not found
# /Users/adamfletcher/Desktop/article_text/20170720100000-T1878.txt not found
# /Users/adamfletcher/Desktop/article_text/20190815100000-556.txt not found
# /Users/adamfletcher/Desktop/article_text/20150513194500-394.txt not found
# /Users/adamfletcher/Desktop/article_text/20151102180000-2619.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128163000-1683.txt not found
# /Users/adamfletcher/Desktop/article_text/20201118193000-1055.txt not found
# /Users/adamfletcher/Desktop/article_text/20160310164500-475.txt not found
# /Users/adamfletcher/Desktop/article_text/20220926051500-549.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128194500-940.txt not found
# /Users/adamfletcher/Desktop/article_text/20160524170000-194.txt not found
# /Users/adamfletcher/Desktop/article_text/20180622024500-1673.txt not found
# /Users/adamfletcher/Desktop/article_text/20171117153000-T466.txt not found
# /Users/adamfletcher/Desktop/article_text/20160209073000-1947.txt not found
# /Users/adamfletcher/Desktop/article_text/20170307160000-547.txt not found
# /Users/adamfletcher/Desktop/article_text/20200128220000-1167.txt not found
# /Users/adamfletcher/Desktop/article_text/20181004200000-2209.txt not found
# /Users/adamfletcher/Desktop/article_text/20150417223000-T723.txt not found
# /Users/adamfletcher/Desktop/article_text/20160209094500-1910.txt not found

# %%
df_embs = df_embs.reset_index(drop=True)
df_full = df.merge(df_embs, on='gkg_record_id', how='left')
df_full.to_csv('articles_with_embeddings.csv')
# Out:
# (50, 2)
