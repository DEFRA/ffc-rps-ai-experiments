# %% [markdown]
# # Split Large Documents
#
# We have a number of genAI applications in which we use LLMs to assess large documents. Some are many times the context window.
#
# There's an interesting approach involving chunking which we're exploring separately, but for one particular extremely large document I'd like to try and do it programmatically. The doc has a table of contents which links to the headings, so I feel there's enough structure there to work with

# %%
import docx
import os

# %% [markdown]
# The below functions were written by ChatGPT3.5turbo for docx. Not tested yet.

# %%
# Function to extract headings from the table of contents
def extract_headings(doc):
    headings = []
    for para in doc.paragraphs:
        if para.style.name.startswith('Heading'):
            headings.append(para.text.strip())
    return headings
# Function to save a section as a new Word file
def save_section(heading, content, output_dir):
    new_doc = docx.Document()
    for para in content:
        new_para = new_doc.add_paragraph(para.text)
        new_para.style = para.style

    # Create a valid filename from the heading
    safe_heading = ''.join(c for c in heading if c.isalnum() or c in (' ', '_')).rstrip()
    filename = f"{safe_heading}.docx"
    file_path = os.path.join(output_dir, filename)

    # Save the new document
    new_doc.save(file_path)
    print(f"Saved section '{heading}' to '{file_path}'")
# Function to split document based on headings
def split_doc_by_headings(doc, headings, output_dir):
    current_section = None
    section_content = []

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for para in doc.paragraphs:
        if para.text.strip() in headings:
            # Save the previous section if any
            if current_section:
                save_section(current_section, section_content, output_dir)
            # Start a new section
            current_section = para.text.strip()
            section_content = []
        section_content.append(para)

    # Save the last section
    if current_section:
        save_section(current_section, section_content, output_dir)
# Main function
def split_document_by_toc(input_doc_path, output_dir):
    # Load the Word document
    doc = docx.Document(input_doc_path)

    # Extract headings from the document
    headings = extract_headings(doc)

    # Split document by headings and save each section
    split_doc_by_headings(doc, headings, output_dir)

# Usage
input_doc_path = "/Users/joe/Documents/git/defra/docs/SFI 2024 actions MASTER v1.1b clean for pdf.odt"
output_dir = "output/folder"
split_document_by_toc(input_doc_path, output_dir)

# %% [markdown]
# The below functions were written by ChatGPT3.5turbo for odf, then had to be heavily modified to make them actually work...

# %%
from odf.opendocument import load
from odf.text import P, H
from odf.opendocument import OpenDocumentText
import os

# Function to extract headings from the document
def extract_headings(doc):
    headings = []
    for element in doc.getElementsByType(H):
        headings.append(element.textContent.strip())
    return headings

# Function to split document based on headings
def split_doc_by_headings(doc, headings, output_dir):
    current_section = None
    section_content = []

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for element in doc.getElementsByType(P):
        if element.textContent.strip() in headings:
            # Save the previous section if any
            if current_section:
                save_section(current_section, section_content, output_dir)
            # Start a new section
            current_section = element.textContent.strip()
            section_content = []
        section_content.append(element)

    # Save the last section
    if current_section:
        save_section(current_section, section_content, output_dir)

# Function to save a section as a new ODT file
def save_section(heading, content, output_dir):
    new_doc = OpenDocumentText()

    for element in content:
        new_para = P(text=element.textContent)
        new_doc.text.addElement(new_para)

    # Create a valid filename from the heading
    safe_heading = ''.join(c for c in heading if c.isalnum() or c in (' ', '_')).rstrip()
    filename = f"{safe_heading}.odt"
    file_path = os.path.join(output_dir, filename)

    # Save the new document
    new_doc.save(file_path)
    print(f"Saved section '{heading}' to '{file_path}'")

# Main function
def split_document_by_toc(input_doc_path, output_dir):
    # Load the ODT document
    doc = load(input_doc_path)

    # Extract headings from the document
    headings = extract_headings(doc)

    # Split document by headings and save each section
    split_doc_by_headings(doc, headings, output_dir)

# %%
# Usage
input_doc_path = "/Users/joe/Documents/git/defra/docs/SFI 2024 actions MASTER v1.1b clean for pdf.odt"
output_dir = "output/expanded_sections"
split_document_by_toc(input_doc_path, output_dir)

# %% [markdown]
# It did not work. Let's unpick it asnd see if the problem's with the document

# %%
doc = load(input_doc_path)

# %%
from odf import text

def get_toc_elements(doc):
    paragraphs = []
    for paragraph in doc.getElementsByType(text.P):
        style = paragraph.getAttribute('stylename')
        if style=='TOC1' or style=='TOC2':
            #print(f"{style}, {paragraph}")
            paragraphs.append(paragraph)

    return paragraphs



paragraphs = get_toc_elements(doc)

# %% [markdown]
# From the above it's clear the doc doesn't use any of the 'H' predefined styles for headings. But we do have a very nice TOC and those bits have to be in the predefined TOC1 and TOC2 styles.
#
# Inspection of the document shows the actions are all TOC2 styles and they're grouped in TOC1 categories that differentiate them based on their purpose. This is something Ian was trying to capture so let's run with that:
#
# - identify all TOC1 headings and the TOC2 ones below each
# - for each TOC2 use the link to identify the corresponding section?
# - split and save in TOC1/TOC2.odt
#
# As suspected, the links in the TOC point to unique anchors. I'm gunna need to know the anchor and the following one. There's a corner case when the TOC2 element is the last in its TOC1, but let's see how we go.
#
# Used the prompt:
#
# `please write code to extract a section of the document without reference to its own style, but using the links associated with a TOC2 element and the subsequent TOC2 element`

# %%
from odf.opendocument import load
from odf.text import P, A, H, TocMark
from odf.opendocument import OpenDocumentText
import os

# Function to extract TOC2 elements and their linked sections
def extract_toc2_sections(doc):
    #toc_entries = []
    # Locate the Table of Contents (TocEntry)
    #toc_entries = doc.getElementsByType(Toc)

    toc_entries = []
    for element in doc.getElementsByType(text.P):
        style = element.getAttribute('stylename')
        if style=='TOC1' or style=='TOC2':
            #print(f"{style}, {paragraph}")
            toc_entries.append(element)

    toc2_elements = []
    # Iterate over all TOC entries to find TOC2 elements
    for toc_entry in toc_entries:
        link_element = toc_entry.getElementsByType(A)
        if link_element:
            link = link_element[0].getAttribute("xlink:href")
            toc2_elements.append((toc_entry.textContent.strip(), link))
    return toc2_elements

# Function to extract the section content between two TOC2 links
def extract_section_by_toc2_links(doc, start_link, end_link):
    in_section = False
    section_content = []

    for para in doc.getElementsByType(P):
        # Check paragraph id (text:id), which may correspond to the TOC link
        para_id = para.getAttribute("text:id")

        if para_id == start_link:
            in_section = True  # Start extracting content when start_link is found

        if in_section:
            section_content.append(para)

        if para_id == end_link:
            break  # Stop extracting when end_link is found

    return section_content

# Function to save the extracted section as a new ODT file
def save_section(content, output_filename):
    new_doc = OpenDocumentText()

    for para in content:
        new_para = P(text=para.textContent)
        new_doc.text.addElement(new_para)

    # Save the new document
    new_doc.save(output_filename)
    print(f"Saved section to '{output_filename}'")

# Main function to extract and save the section between two TOC2 elements
def extract_and_save_section_by_toc2(input_doc_path, toc2_start, toc2_end, output_filename):
    # Load the ODT document
    doc = load(input_doc_path)

    # Get TOC2 elements and their links
    #toc2_elements = extract_toc2_sections(doc)
    toc2_elements = get_toc_elements(doc)

    # Find the start and end TOC2 links
    start_link = end_link = None
    for toc2_title, link in toc2_elements:
        if toc2_title == toc2_start:
            start_link = link
        if toc2_title == toc2_end:
            end_link = link
            break

    # Check if both start and end links were found
    if not start_link or not end_link:
        raise ValueError(f"Could not find start or end TOC2 elements: {toc2_start}, {toc2_end}")

    # Extract section between these TOC2 links
    section_content = extract_section_by_toc2_links(doc, start_link, end_link)

    # Save the extracted section as a new ODT file
    save_section(section_content, output_filename)

# %%
# Usage example
input_doc_path = "/Users/joe/Documents/git/defra/docs/SFI 2024 actions MASTER v1.1b clean for pdf.odt"
toc2_start = "CSAM1: Assess soil, produce a soil management plan and test soil organic matter"  # Title of the starting TOC2 section
toc2_end = "CNUM3: Legume fallow"  # Title of the ending TOC2 section
output_filename = "output_section.odt"

extract_and_save_section_by_toc2(input_doc_path, toc2_start, toc2_end, output_filename)

# %%
toc2_elements = extract_toc2_sections(doc)
toc2_elements

# %%
toc_entries = []
for element in doc.getElementsByType(text.P):
    style = element.getAttribute('stylename')
    if style=='TOC1' or style=='TOC2':
        #print(f"{style}, {paragraph}")
        toc_entries.append(element)

toc_entries
# Out:
# [<odf.element.Element at 0x123adcfe0>,
#  <odf.element.Element at 0x123add3a0>,
#  <odf.element.Element at 0x123add6d0>,
#  <odf.element.Element at 0x123adda30>,
#  <odf.element.Element at 0x123addd90>,
#  <odf.element.Element at 0x123ade0f0>,
#  <odf.element.Element at 0x123ade450>,
#  <odf.element.Element at 0x123ade7b0>,
#  <odf.element.Element at 0x123adeb10>,
#  <odf.element.Element at 0x123adee70>,
#  <odf.element.Element at 0x123adf350>,
#  <odf.element.Element at 0x123adf6b0>,
#  <odf.element.Element at 0x123adfa10>,
#  <odf.element.Element at 0x123adfd70>,
#  <odf.element.Element at 0x123afc110>,
#  <odf.element.Element at 0x123afc470>,
#  <odf.element.Element at 0x123afc7d0>,
#  <odf.element.Element at 0x123afcb30>,
#  <odf.element.Element at 0x123afce90>,
#  <odf.element.Element at 0x123afd1f0>,
#  <odf.element.Element at 0x123afd550>,
#  <odf.element.Element at 0x123afd8b0>,
#  <odf.element.Element at 0x123afdc10>,
#  <odf.element.Element at 0x123afdf70>,
#  <odf.element.Element at 0x123afe2d0>,
#  <odf.element.Element at 0x123afe630>,
#  <odf.element.Element at 0x123afe990>,
#  <odf.element.Element at 0x123afecf0>,
#  <odf.element.Element at 0x123aff050>,
#  <odf.element.Element at 0x123aff3b0>,
#  <odf.element.Element at 0x123aff710>,
#  <odf.element.Element at 0x123affaa0>,
#  <odf.element.Element at 0x123affe30>,
#  <odf.element.Element at 0x123b101d0>,
#  <odf.element.Element at 0x123b10530>,
#  <odf.element.Element at 0x123b10890>,
#  <odf.element.Element at 0x123b10bf0>,
#  <odf.element.Element at 0x123b10f50>,
#  <odf.element.Element at 0x123b112b0>,
#  <odf.element.Element at 0x123b11610>,
#  <odf.element.Element at 0x123b11970>,
#  <odf.element.Element at 0x123b11cd0>,
#  <odf.element.Element at 0x123b12030>,
#  <odf.element.Element at 0x123b12390>,
#  <odf.element.Element at 0x123b126f0>,
#  <odf.element.Element at 0x123b12a50>,
#  <odf.element.Element at 0x123b12db0>,
#  <odf.element.Element at 0x123b13110>,
#  <odf.element.Element at 0x123b13470>,
#  <odf.element.Element at 0x123b137d0>,
#  <odf.element.Element at 0x123b13b30>,
#  <odf.element.Element at 0x123b13e90>,
#  <odf.element.Element at 0x123b24230>,
#  <odf.element.Element at 0x123b24590>,
#  <odf.element.Element at 0x123b248f0>,
#  <odf.element.Element at 0x123b24c50>,
#  <odf.element.Element at 0x123b24fb0>,
#  <odf.element.Element at 0x123b25310>,
#  <odf.element.Element at 0x123b25670>,
#  <odf.element.Element at 0x123b259d0>,
#  <odf.element.Element at 0x123b25d30>,
#  <odf.element.Element at 0x123b26090>,
#  <odf.element.Element at 0x123b263f0>,
#  <odf.element.Element at 0x123b26750>,
#  <odf.element.Element at 0x123b26ab0>,
#  <odf.element.Element at 0x123b26e10>,
#  <odf.element.Element at 0x123b27170>,
#  <odf.element.Element at 0x123b274d0>,
#  <odf.element.Element at 0x123b27830>,
#  <odf.element.Element at 0x123b27b90>,
#  <odf.element.Element at 0x123b27ef0>,
#  <odf.element.Element at 0x123b3c290>,
#  <odf.element.Element at 0x123b3c5f0>,
#  <odf.element.Element at 0x123b3c950>,
#  <odf.element.Element at 0x123b3ccb0>,
#  <odf.element.Element at 0x123b3d010>,
#  <odf.element.Element at 0x123b3d370>,
#  <odf.element.Element at 0x123b3d6d0>,
#  <odf.element.Element at 0x123b3da30>,
#  <odf.element.Element at 0x123b3dd90>,
#  <odf.element.Element at 0x123b3e0f0>,
#  <odf.element.Element at 0x123b3e450>,
#  <odf.element.Element at 0x123b3e7b0>,
#  <odf.element.Element at 0x123b3eb10>,
#  <odf.element.Element at 0x123b3ee70>,
#  <odf.element.Element at 0x123b3f1d0>,
#  <odf.element.Element at 0x123b3f530>,
#  <odf.element.Element at 0x123b3f890>,
#  <odf.element.Element at 0x123b3fbf0>,
#  <odf.element.Element at 0x123b3ff50>,
#  <odf.element.Element at 0x123b50320>,
#  <odf.element.Element at 0x123b50680>,
#  <odf.element.Element at 0x123b509e0>,
#  <odf.element.Element at 0x123b50d40>,
#  <odf.element.Element at 0x123b510a0>,
#  <odf.element.Element at 0x123b51400>,
#  <odf.element.Element at 0x123b51760>,
#  <odf.element.Element at 0x123b51ac0>,
#  <odf.element.Element at 0x123b51e20>,
#  <odf.element.Element at 0x123b52180>,
#  <odf.element.Element at 0x123b524e0>,
#  <odf.element.Element at 0x123b52840>,
#  <odf.element.Element at 0x123b52ba0>,
#  <odf.element.Element at 0x123b52f00>,
#  <odf.element.Element at 0x123b53260>,
#  <odf.element.Element at 0x123b535c0>,
#  <odf.element.Element at 0x123b53920>,
#  <odf.element.Element at 0x123b53c80>,
#  <odf.element.Element at 0x123b53fe0>,
#  <odf.element.Element at 0x123b6c380>,
#  <odf.element.Element at 0x123b6c6e0>,
#  <odf.element.Element at 0x123b6ca40>,
#  <odf.element.Element at 0x123b6cda0>,
#  <odf.element.Element at 0x123b6d100>,
#  <odf.element.Element at 0x123b6d460>,
#  <odf.element.Element at 0x123b6d7c0>]

# %%
print(toc_entries[0].getElementsByType(A)[0])
# Out:
# SFI actions for soil health5

# %%
toc2_elements = []
# Iterate over all TOC entries to find TOC2 elements
for toc_entry in toc_entries:
    link_element = toc_entry.getElementsByType(A)
    if link_element:
        link = link_element[0].getAttribute("xlink:href")
        toc2_elements.append((toc_entry.textContent.strip(), link))

# %% [markdown]
# This all doesn't seem to work. I suspect the bit of code that handles these `TocMark` elements doesn't work on the `P` elements the revised version is returning - none of them have hrefs. The documentation is pretty difficult to work with but given that I've identified the text of the TOC21 headings I'm going to try using text scanning instead.

# %%
from odf.opendocument import load, OpenDocumentText
from odf.text import P

def extract_section_by_strings(input_doc_path, start_string, end_string, output_doc_path):
    # Load the ODT document
    doc = load(input_doc_path)

    # Variables to track extraction status
    in_section = False
    section_content = []

    # Iterate over paragraphs in the document
    for para in doc.getElementsByType(P):
        para_text = para.textContent

        # Check if the current paragraph contains the starting string
        if start_string in para_text:
            in_section = True

        # If in the section, add the paragraph to the section content
        if in_section:
            section_content.append(para)

        # Check if the current paragraph contains the ending string
        if end_string in para_text and in_section:
            break  # Stop extraction after the end string is found

    # Create a new ODT document for the extracted content
    new_doc = OpenDocumentText()

    # Add the extracted section content to the new document
    for para in section_content:
        new_para = P(text=para.textContent)
        new_doc.text.addElement(new_para)

    # Save the new document
    new_doc.save(output_doc_path)
    print(f"Section saved as '{output_doc_path}'")

# Usage example
input_doc_path = "/Users/joe/Documents/git/defra/docs/SFI 2024 actions MASTER v1.1b clean for pdf.odt"
start_string = "CSAM1: Assess soil, produce a soil management plan and test soil organic matter"  # The string where the section starts
end_string = "CSAM2: Multi-species winter cover crop"  # The string where the section ends
output_doc_path = "extracted_section.odt"  # The path to save the new document

extract_section_by_strings(input_doc_path, start_string, end_string, output_doc_path)

# %% [markdown]
# We're not getting anywhere with odfpy. It's not been maintained for ages and chatgpt seems to be using quite old docs which I'm guessing are deprecated. `odfdo` seems to be newer, let's try again with that

# %%
from odfdo import Document, Paragraph

def extract_section_by_toc2(input_doc_path, toc2_start_title, toc2_end_title, output_doc_path):
    # Load the ODT document
    doc = Document(input_doc_path)

    # Get the content of the document
    body = doc.body

    # Variables to track extraction status
    in_section = False
    section_content = []

    # Function to find bookmarks associated with TOC2 titles
    def find_toc2_bookmark(toc_title):
        for element in body.get_elements():
            if isinstance(element, Paragraph):
                if toc_title in element.text():
                    # Return the bookmark ID
                    bookmarks = element.get_links()
                    if bookmarks:
                        return bookmarks[0]  # Assume first link is correct
        return None

    # Find the start and end bookmarks based on the TOC2 titles
    start_bookmark = find_toc2_bookmark(toc2_start_title)
    end_bookmark = find_toc2_bookmark(toc2_end_title)

    if not start_bookmark or not end_bookmark:
        raise ValueError(f"Could not find TOC2 elements for: {toc2_start_title} and {toc2_end_title}")

    # Extract paragraphs between the start and end bookmarks
    for element in body.get_elements():
        if isinstance(element, Paragraph):
            # Check if the current element contains the start bookmark
            if start_bookmark in element.text():
                in_section = True

            if in_section:
                section_content.append(element)

            # Check if the current element contains the end bookmark
            if end_bookmark in element.text():
                break

    # Create a new document for the extracted content
    new_doc = Document()

    # Add the extracted content to the new document
    new_body = new_doc.body
    for para in section_content:
        new_body.append(para)

    # Save the new document
    new_doc.save(output_doc_path)
    print(f"Extracted section saved as '{output_doc_path}'")

# Usage example
input_doc_path = "/Users/joe/Documents/git/defra/docs/SFI 2024 actions MASTER v1.1b clean for pdf.odt"
toc2_start_title = "CSAM1: Assess soil, produce a soil management plan and test soil organic matter"  # Title of the TOC2 section to start extraction
toc2_end_title = "CSAM2: Multi-species winter cover crop"  # Title of the TOC2 section to end extraction
output_doc_path = "extracted_section.odt"  # Path to save the new document

extract_section_by_toc2(input_doc_path, toc2_start_title, toc2_end_title, output_doc_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 64
#      61 toc2_end_title = "CSAM2: Multi-species winter cover crop"  # Title of the TOC2 section to end extraction
#      62 output_doc_path = "extracted_section.odt"  # Path to save the new document
# ---> 64 extract_section_by_toc2(input_doc_path, toc2_start_title, toc2_end_title, output_doc_path)
#
# Cell In[54], line 26, in extract_section_by_toc2(input_doc_path, toc2_start_title, toc2_end_title, output_doc_path)
#      23     return None
#      25 # Find the start and end bookmarks based on the TOC2 titles
# ---> 26 start_bookmark = find_toc2_bookmark(toc2_start_title)
#      27 end_bookmark = find_toc2_bookmark(toc2_end_title)
#      29 if not start_bookmark or not end_bookmark:
#
# Cell In[54], line 16, in extract_section_by_toc2.<locals>.find_toc2_bookmark(toc_title)
#      15 def find_toc2_bookmark(toc_title):
# ---> 16     for element in body.get_elements():
#      17         if isinstance(element, Paragraph):
#      18             if toc_title in element.text():
#      19                 # Return the bookmark ID
#
# TypeError: Element.get_elements() missing 1 required positional argument: 'xpath_query'

# %% [markdown]
# I've converted the document to docx, which I suspect is where it started (hence not having all the right style labels). Let's see if we can do this with the docx library instead.

# %%
from docx import Document

def extract_toc_entries(docx_path):
    # Load the DOCX document
    doc = Document(docx_path)

    # List to store the extracted TOC entries
    toc_entries = []

    # Iterate over paragraphs in the document
    for para in doc.paragraphs:
        # Check if the paragraph style is related to TOC (e.g., TOC1, TOC2, etc.)
        if para.style.name.startswith('TOC'):
            toc_entries.append(para.text)

    return toc_entries

# Usage example
docx_path = "/Users/joe/Documents/git/defra/docs/SFI 2024 actions MASTER v1.1b clean for pdf.docx"
toc_entries = extract_toc_entries(docx_path)

# Print the extracted TOC entries
for i, entry in enumerate(toc_entries, 1):
    print(f"{i}. {entry}")
# Out:
# 1. photographs or other documentation

# %%
doc = Document(docx_path)
for para in doc.paragraphs:
    print(para.style.name)
# Out:
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 2
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# bullet
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# paragraph
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# paragraph
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 4
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 4
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# paragraph
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# List Paragraph
# bullet
# bullet
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# bullet
# List Paragraph
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# bullet
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Normal (Web)
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# bullet
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# Heading 3
# Heading 3
# Heading 3
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# bullet
# List Paragraph
# LO-Normal
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# ...
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# Heading 4
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Normal (Web)
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 1
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# Heading 2
# LO-Normal
# LO-Normal
# LO-Normal
# paragraph
# paragraph
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# bullet
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# LO-Normal
# bullet
# bullet
# bullet
# bullet
# bullet
# bullet
# LO-Normal
# bullet
# bullet
# LO-Normal
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# bullet
# bullet
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# LO-Normal
# Heading 2
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# Heading 4
# Heading 4
# Heading 4
# LO-Normal
# LO-Normal
# Heading 4
# LO-Normal
# Heading 4
# LO-Normal
# bullet
# bullet
# Heading 3
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# List Paragraph
# List Paragraph
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# List Paragraph
# LO-Normal
# Heading 3
# LO-Normal
# List Paragraph
# TOC 2
# LO-Normal
# Heading 3
# LO-Normal
# LO-Normal
# LO-Normal
# bullet
# List Paragraph
# List Paragraph
# List Paragraph
# List Paragraph
# LO-Normal
# LO-Normal
# LO-Normal

# %%
from docx import Document
import os

def split_doc_by_heading2(docx_path, output_dir):
    # Load the DOCX document
    doc = Document(docx_path)

    # Make sure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Variables to store the current section and its heading
    current_section = []
    current_heading = None

    # Function to save the current section to a new document
    def save_section(heading, content):
        # Create a new document
        new_doc = Document()

        # Add content to the new document
        for para in content:
            new_doc.add_paragraph(para.text)

        # Clean the heading to make it a valid filename
        clean_heading = ''.join(c for c in heading if c.isalnum() or c in ' ').strip()
        file_name = f"{clean_heading}.docx"
        output_path = os.path.join(output_dir, file_name)

        # Save the new document
        new_doc.save(output_path)
        print(f"Section '{heading}' saved as {output_path}")

    # Iterate over the paragraphs in the document
    for para in doc.paragraphs:
        # Check if the paragraph style is 'Heading 2'
        if para.style.name == 'Heading 2':
            # If we are in a section, save the previous section
            if current_heading and current_section:
                save_section(current_heading, current_section)
                current_section = []  # Reset the section content

            # Update the current heading to the new Heading 2 text
            current_heading = para.text

        # Add the current paragraph to the current section
        if current_heading:
            current_section.append(para)

    # Save the last section
    if current_heading and current_section:
        save_section(current_heading, current_section)

# Usage example
input_docx_path = "/Users/joe/Documents/git/defra/docs/SFI 2024 actions MASTER v1.1b clean for pdf.docx"
output_directory = "output/expanded_sections"  # Directory to save the split sections

split_doc_by_heading2(input_docx_path, output_directory)
# Out:
# Section 'CSAM1: Assess soil, produce a soil management plan and test soil organic matter' saved as output/expanded_sections/CSAM1 Assess soil produce a soil management plan and test soil organic matter.docx
# Section 'CSAM2: Multi-species winter cover crop' saved as output/expanded_sections/CSAM2 Multispecies winter cover crop.docx
# Section 'CSAM3: Herbal leys' saved as output/expanded_sections/CSAM3 Herbal leys.docx
# Section 'SOH1: No-till farming' saved as output/expanded_sections/SOH1 Notill farming.docx
# Section 'SOH2: Multi-species spring-sown cover crop ' saved as output/expanded_sections/SOH2 Multispecies springsown cover crop.docx
# Section 'SOH3: Multi-species summer-sown cover crop' saved as output/expanded_sections/SOH3 Multispecies summersown cover crop.docx
# Section 'SOH4: Winter cover following maize crops ' saved as output/expanded_sections/SOH4 Winter cover following maize crops.docx
# Section 'AGF1: Maintain very low density in-field agroforestry on less sensitive land' saved as output/expanded_sections/AGF1 Maintain very low density infield agroforestry on less sensitive land.docx
# Section 'AGF2: Maintain low density in-field agroforestry on less sensitive land ' saved as output/expanded_sections/AGF2 Maintain low density infield agroforestry on less sensitive land.docx
# Section 'CHRW1: Assess and record hedgerow condition' saved as output/expanded_sections/CHRW1 Assess and record hedgerow condition.docx
# Section 'CHRW2: Manage hedgerows' saved as output/expanded_sections/CHRW2 Manage hedgerows.docx
# Section 'CHRW3: Maintain or establish hedgerow trees' saved as output/expanded_sections/CHRW3 Maintain or establish hedgerow trees.docx
# Section 'BND1: Maintain dry stone walls' saved as output/expanded_sections/BND1 Maintain dry stone walls.docx
# Section 'BND2: Maintain earth banks or stone-faced hedgebanks' saved as output/expanded_sections/BND2 Maintain earth banks or stonefaced hedgebanks.docx
# Section 'CAHL4: 4m to 12m grass buffer strip on arable and horticultural land' saved as output/expanded_sections/CAHL4 4m to 12m grass buffer strip on arable and horticultural land.docx
# Section 'CIGL3: 4m to 12m grass buffer strip on improved grassland' saved as output/expanded_sections/CIGL3 4m to 12m grass buffer strip on improved grassland.docx
# Section 'BFS1: 12m to 24m watercourse buffer strip on cultivated land' saved as output/expanded_sections/BFS1 12m to 24m watercourse buffer strip on cultivated land.docx
# Section 'BFS2: Buffer in-field ponds on arable land' saved as output/expanded_sections/BFS2 Buffer infield ponds on arable land.docx
# Section 'BFS3: Buffer in-field ponds on improved grassland' saved as output/expanded_sections/BFS3 Buffer infield ponds on improved grassland.docx
# Section 'BFS4: Protect in-field trees on arable land' saved as output/expanded_sections/BFS4 Protect infield trees on arable land.docx
# Section 'BFS5: Protect in-field trees on intensive grassland ' saved as output/expanded_sections/BFS5 Protect infield trees on intensive grassland.docx
# Section 'BFS6: 6m to 12m habitat strip next to watercourses ' saved as output/expanded_sections/BFS6 6m to 12m habitat strip next to watercourses.docx
# Section 'WBD1: Manage ponds ' saved as output/expanded_sections/WBD1 Manage ponds.docx
# Section 'WBD2: Manage ditches ' saved as output/expanded_sections/WBD2 Manage ditches.docx
# Section 'WBD3: In-field grass strips ' saved as output/expanded_sections/WBD3 Infield grass strips.docx
# Section 'WBD4: Arable reversion to grassland with low fertiliser input' saved as output/expanded_sections/WBD4 Arable reversion to grassland with low fertiliser input.docx
# Section 'WBD5: Manage intensive grassland adjacent to a watercourse ' saved as output/expanded_sections/WBD5 Manage intensive grassland adjacent to a watercourse.docx
# Section 'WBD6: Remove livestock from intensive grassland during the autumn and winter (outside SDAs)' saved as output/expanded_sections/WBD6 Remove livestock from intensive grassland during the autumn and winter outside SDAs.docx
# Section 'WBD7: Remove livestock from grassland during the autumn and winter (SDAs)' saved as output/expanded_sections/WBD7 Remove livestock from grassland during the autumn and winter SDAs.docx
# Section 'WBD8: Manage grassland to reduce nutrient levels in groundwater' saved as output/expanded_sections/WBD8 Manage grassland to reduce nutrient levels in groundwater.docx
# Section 'WBD9: Nil fertiliser supplement' saved as output/expanded_sections/WBD9 Nil fertiliser supplement.docx
# Section 'OFC1: Organic conversion – improved permanent grassland' saved as output/expanded_sections/OFC1 Organic conversion  improved permanent grassland.docx
# Section 'OFC2: Organic conversion – unimproved permanent grassland' saved as output/expanded_sections/OFC2 Organic conversion  unimproved permanent grassland.docx
# Section 'OFC3: Organic conversion – rotational land' saved as output/expanded_sections/OFC3 Organic conversion  rotational land.docx
# Section 'OFC4: Organic conversion – horticultural land' saved as output/expanded_sections/OFC4 Organic conversion  horticultural land.docx
# Section 'OFC5: Organic conversion – top fruit' saved as output/expanded_sections/OFC5 Organic conversion  top fruit.docx
# Section 'OFM1: Organic land management – improved permanent grassland' saved as output/expanded_sections/OFM1 Organic land management  improved permanent grassland.docx
# Section 'OFM2: Organic land management – unimproved permanent grassland ' saved as output/expanded_sections/OFM2 Organic land management  unimproved permanent grassland.docx
# Section 'OFM3: Organic land management – enclosed rough grazing' saved as output/expanded_sections/OFM3 Organic land management  enclosed rough grazing.docx
# Section 'OFM4: Organic land management – rotational land ' saved as output/expanded_sections/OFM4 Organic land management  rotational land.docx
# Section 'OFM5: Organic land management – horticultural land ' saved as output/expanded_sections/OFM5 Organic land management  horticultural land.docx
# Section 'OFM6: Organic land management – top fruit' saved as output/expanded_sections/OFM6 Organic land management  top fruit.docx
# Section 'OFA1: Overwinter stubble (organic land)' saved as output/expanded_sections/OFA1 Overwinter stubble organic land.docx
# Section 'OFA3: Supplementary winter bird food (organic land)' saved as output/expanded_sections/OFA3 Supplementary winter bird food organic land.docx
# Section 'OFA6: Undersown cereal crop (organic land)' saved as output/expanded_sections/OFA6 Undersown cereal crop organic land.docx
# Section 'CAHL1: Pollen and nectar flower mix' saved as output/expanded_sections/CAHL1 Pollen and nectar flower mix.docx
# Section 'CAHL2: Winter bird food on arable and horticultural land ' saved as output/expanded_sections/CAHL2 Winter bird food on arable and horticultural land.docx
# Section 'CAHL3: Grassy field corners or blocks' saved as output/expanded_sections/CAHL3 Grassy field corners or blocks.docx
# Section 'AHW1: Bumblebird mix' saved as output/expanded_sections/AHW1 Bumblebird mix.docx
# Section 'AHW2: Supplementary winter bird food ' saved as output/expanded_sections/AHW2 Supplementary winter bird food.docx
# Section 'AHW3: Beetle banks   ' saved as output/expanded_sections/AHW3 Beetle banks.docx
# Section 'AHW4: Skylark plots ' saved as output/expanded_sections/AHW4 Skylark plots.docx
# Section 'AHW5: Nesting plots for lapwing ' saved as output/expanded_sections/AHW5 Nesting plots for lapwing.docx
# Section 'AHW6: Basic overwinter stubble ' saved as output/expanded_sections/AHW6 Basic overwinter stubble.docx
# Section 'AHW7: Enhanced overwinter stubble' saved as output/expanded_sections/AHW7 Enhanced overwinter stubble.docx
# Section 'AHW8: Whole crop spring cereals and overwinter stubble' saved as output/expanded_sections/AHW8 Whole crop spring cereals and overwinter stubble.docx
# Section 'AHW9: Unharvested cereal headland' saved as output/expanded_sections/AHW9 Unharvested cereal headland.docx
# Section 'AHW10: Low input harvested cereal crop' saved as output/expanded_sections/AHW10 Low input harvested cereal crop.docx
# Section 'AHW11: Cultivated areas for arable plants' saved as output/expanded_sections/AHW11 Cultivated areas for arable plants.docx
# Section 'AHW12: Manage woodland edges on arable land' saved as output/expanded_sections/AHW12 Manage woodland edges on arable land.docx
# Section 'CMOR1: Assess moorland and produce a written record' saved as output/expanded_sections/CMOR1 Assess moorland and produce a written record.docx
# Section 'UPL1: Moderate livestock grazing on moorland' saved as output/expanded_sections/UPL1 Moderate livestock grazing on moorland.docx
# Section 'UPL2: Low livestock grazing on moorland' saved as output/expanded_sections/UPL2 Low livestock grazing on moorland.docx
# Section 'UPL3: Limited livestock grazing on moorland' saved as output/expanded_sections/UPL3 Limited livestock grazing on moorland.docx
# Section 'UPL4: Keep cattle and ponies on moorland supplement (minimum 30% GLU)' saved as output/expanded_sections/UPL4 Keep cattle and ponies on moorland supplement minimum 30 GLU.docx
# Section 'UPL5: Keep cattle and ponies on moorland supplement (minimum 70% GLU)' saved as output/expanded_sections/UPL5 Keep cattle and ponies on moorland supplement minimum 70 GLU.docx
# Section 'UPL6: Keep cattle and ponies on moorland supplement (100% GLU)' saved as output/expanded_sections/UPL6 Keep cattle and ponies on moorland supplement 100 GLU.docx
# Section 'UPL7: Shepherding livestock on moorland (no required stock removal period)' saved as output/expanded_sections/UPL7 Shepherding livestock on moorland no required stock removal period.docx
# Section 'UPL8: Shepherding livestock on moorland (remove stock for at least 4 months)' saved as output/expanded_sections/UPL8 Shepherding livestock on moorland remove stock for at least 4 months.docx
# Section 'UPL9: Shepherding livestock on moorland (remove stock for at least 6 months)' saved as output/expanded_sections/UPL9 Shepherding livestock on moorland remove stock for at least 6 months.docx
# Section 'UPL10: Shepherding livestock on moorland (remove stock for at least 8 months)' saved as output/expanded_sections/UPL10 Shepherding livestock on moorland remove stock for at least 8 months.docx
# Section 'PRF1: Variable rate application of nutrients' saved as output/expanded_sections/PRF1 Variable rate application of nutrients.docx
# Section 'PRF2: Camera or remote sensor guided herbicide spraying' saved as output/expanded_sections/PRF2 Camera or remote sensor guided herbicide spraying.docx
# Section 'PRF3: Non-mechanical robotic weeding' saved as output/expanded_sections/PRF3 Nonmechanical robotic weeding.docx
# Section 'PRF4: Mechanical robotic weeding' saved as output/expanded_sections/PRF4 Mechanical robotic weeding.docx
# Section 'CIGL1: Take grassland field corners or blocks out of management' saved as output/expanded_sections/CIGL1 Take grassland field corners or blocks out of management.docx
# Section 'CIGL2: Winter bird food on improved grassland' saved as output/expanded_sections/CIGL2 Winter bird food on improved grassland.docx
# Section 'CLIG3: Manage grassland with very low nutrient inputs' saved as output/expanded_sections/CLIG3 Manage grassland with very low nutrient inputs.docx
# Section 'GRH1: Manage rough grazing for birds  ' saved as output/expanded_sections/GRH1 Manage rough grazing for birds.docx
# Section 'GRH7: Haymaking supplement   ' saved as output/expanded_sections/GRH7 Haymaking supplement.docx
# Section 'GRH8: Haymaking supplement (late cut)' saved as output/expanded_sections/GRH8 Haymaking supplement late cut.docx
# Section 'GRH10: Lenient grazing supplement' saved as output/expanded_sections/GRH10 Lenient grazing supplement.docx
# Section 'GRH11: Cattle grazing supplement (non-moorland)' saved as output/expanded_sections/GRH11 Cattle grazing supplement nonmoorland.docx
# Section 'SCR1: Create scrub and open habitat mosaics' saved as output/expanded_sections/SCR1 Create scrub and open habitat mosaics.docx
# Section 'SCR2: Manage scrub and open habitat mosaics' saved as output/expanded_sections/SCR2 Manage scrub and open habitat mosaics.docx
# Section 'HEF1: Maintain weatherproof traditional farm or forestry buildings ' saved as output/expanded_sections/HEF1 Maintain weatherproof traditional farm or forestry buildings.docx
# Section 'HEF2: Maintain weatherproof traditional farm or forestry buildings in remote areas' saved as output/expanded_sections/HEF2 Maintain weatherproof traditional farm or forestry buildings in remote areas.docx
# Section 'HEF5: Control scrub on historic and archaeological features' saved as output/expanded_sections/HEF5 Control scrub on historic and archaeological features.docx
# Section 'HEF6: Manage historic and archaeological features on grassland' saved as output/expanded_sections/HEF6 Manage historic and archaeological features on grassland.docx
# Section 'HEF8: Maintain designed or engineered waterbodies' saved as output/expanded_sections/HEF8 Maintain designed or engineered waterbodies.docx
# Section 'SPM2: Keep native breeds on grazed habitats supplement (50-80%)' saved as output/expanded_sections/SPM2 Keep native breeds on grazed habitats supplement 5080.docx
# Section 'SPM3: Keep native breeds on grazed habitats supplement (more than 80%)' saved as output/expanded_sections/SPM3 Keep native breeds on grazed habitats supplement more than 80.docx
# Section 'SPM4: Keep native breeds on extensively managed habitats supplement (50-80%)' saved as output/expanded_sections/SPM4 Keep native breeds on extensively managed habitats supplement 5080.docx
# Section 'SPM5: Keep native breeds on extensively managed habitats supplement (more than 80%)' saved as output/expanded_sections/SPM5 Keep native breeds on extensively managed habitats supplement more than 80.docx
# Section 'CIPM1: Assess integrated pest management and produce a plan' saved as output/expanded_sections/CIPM1 Assess integrated pest management and produce a plan.docx
# Section 'CIPM2: Flower-rich grass margins, blocks or in-field strips' saved as output/expanded_sections/CIPM2 Flowerrich grass margins blocks or infield strips.docx
# Section 'CIPM3: Companion crop on arable and horticultural land' saved as output/expanded_sections/CIPM3 Companion crop on arable and horticultural land.docx
# Section 'CIPM4: No use of insecticide on arable crops and permanent crops ' saved as output/expanded_sections/CIPM4 No use of insecticide on arable crops and permanent crops.docx
# Section 'CNUM1: Assess nutrient management and produce a review report' saved as output/expanded_sections/CNUM1 Assess nutrient management and produce a review report.docx
# Section 'CNUM2: Legumes on improved grassland  ' saved as output/expanded_sections/CNUM2 Legumes on improved grassland.docx
# Section 'CNUM3: Legume fallow  ' saved as output/expanded_sections/CNUM3 Legume fallow.docx

# %% [markdown]
# Got there in the end!
#
# We'd now like to convert all those docx files to .txt files, they'll be easier to read back in

# %%
from docx import Document
from pathlib import Path

def create_new_file_path(file_path, new_extension):
    # Convert the file_path to a Path object
    original_path = Path(file_path)

    # Create a new 'txt' subdirectory under the original directory
    new_dir = original_path.parent / 'txt'
    new_dir.mkdir(exist_ok=True)  # Create the 'txt' subdirectory if it doesn't exist

    # Create a new file path with the same name but a different extension
    new_file_path = new_dir / original_path.with_suffix(new_extension).name

    return new_file_path

def save_docx_as_txt(docx_dir):
    file_list = [f for f in Path(docx_dir).resolve().glob('**/*.docx') if f.is_file()]
    for docx_path in file_list:
        # Load the DOCX document
        doc = Document(docx_path)

        # generate the output filepath
        txt_path = create_new_file_path(docx_path, '.txt')

        # Open the .txt file for writing
        with open(txt_path, 'w', encoding='utf-8') as txt_file:
            # Iterate through all the paragraphs in the document
            for para in doc.paragraphs:
                # Write the paragraph text followed by a newline
                txt_file.write(para.text + '\n')

        print(f"Document saved as '{txt_path}'")

# Usage example
docx_dir = "/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections"

save_docx_as_txt(docx_dir)
# Out:
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD7 Remove livestock from grassland during the autumn and winter SDAs.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW1 Bumblebird mix.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL3 Limited livestock grazing on moorland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CIPM2 Flowerrich grass margins blocks or infield strips.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL10 Shepherding livestock on moorland remove stock for at least 8 months.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFM2 Organic land management  unimproved permanent grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL8 Shepherding livestock on moorland remove stock for at least 4 months.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL5 Keep cattle and ponies on moorland supplement minimum 70 GLU.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CHRW3 Maintain or establish hedgerow trees.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BFS4 Protect infield trees on arable land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW5 Nesting plots for lapwing.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CIPM1 Assess integrated pest management and produce a plan.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/HEF1 Maintain weatherproof traditional farm or forestry buildings.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CAHL4 4m to 12m grass buffer strip on arable and horticultural land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AGF2 Maintain low density infield agroforestry on less sensitive land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CAHL2 Winter bird food on arable and horticultural land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SOH1 Notill farming.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CSAM2 Multispecies winter cover crop.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BFS2 Buffer infield ponds on arable land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFC3 Organic conversion  rotational land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AGF1 Maintain very low density infield agroforestry on less sensitive land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BFS6 6m to 12m habitat strip next to watercourses.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CSAM3 Herbal leys.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFC1 Organic conversion  improved permanent grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFA6 Undersown cereal crop organic land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CIPM3 Companion crop on arable and horticultural land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/GRH11 Cattle grazing supplement nonmoorland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW8 Whole crop spring cereals and overwinter stubble.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL1 Moderate livestock grazing on moorland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/PRF4 Mechanical robotic weeding.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFM5 Organic land management  horticultural land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW11 Cultivated areas for arable plants.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CNUM2 Legumes on improved grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SPM4 Keep native breeds on extensively managed habitats supplement 5080.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/HEF6 Manage historic and archaeological features on grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CAHL3 Grassy field corners or blocks.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFM4 Organic land management  rotational land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD3 Infield grass strips.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW10 Low input harvested cereal crop.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SOH4 Winter cover following maize crops.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CIGL1 Take grassland field corners or blocks out of management.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFM1 Organic land management  improved permanent grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SPM3 Keep native breeds on grazed habitats supplement more than 80.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/GRH7 Haymaking supplement.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/HEF8 Maintain designed or engineered waterbodies.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFC2 Organic conversion  unimproved permanent grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BND2 Maintain earth banks or stonefaced hedgebanks.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/PRF2 Camera or remote sensor guided herbicide spraying.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/GRH1 Manage rough grazing for birds.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SCR2 Manage scrub and open habitat mosaics.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD2 Manage ditches.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CNUM1 Assess nutrient management and produce a review report.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD6 Remove livestock from intensive grassland during the autumn and winter outside SDAs.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SPM5 Keep native breeds on extensively managed habitats supplement more than 80.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL2 Low livestock grazing on moorland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CIGL3 4m to 12m grass buffer strip on improved grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW12 Manage woodland edges on arable land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFM6 Organic land management  top fruit.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFM3 Organic land management  enclosed rough grazing.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/GRH8 Haymaking supplement late cut.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SOH3 Multispecies summersown cover crop.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW3 Beetle banks.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW2 Supplementary winter bird food.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD1 Manage ponds.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CAHL1 Pollen and nectar flower mix.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BND1 Maintain dry stone walls.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/HEF2 Maintain weatherproof traditional farm or forestry buildings in remote areas.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SCR1 Create scrub and open habitat mosaics.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW6 Basic overwinter stubble.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BFS1 12m to 24m watercourse buffer strip on cultivated land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW4 Skylark plots.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/PRF1 Variable rate application of nutrients.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFC5 Organic conversion  top fruit.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFA1 Overwinter stubble organic land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/PRF3 Nonmechanical robotic weeding.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CNUM3 Legume fallow.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFA3 Supplementary winter bird food organic land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CSAM1 Assess soil produce a soil management plan and test soil organic matter.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SPM2 Keep native breeds on grazed habitats supplement 5080.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD5 Manage intensive grassland adjacent to a watercourse.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW7 Enhanced overwinter stubble.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/OFC4 Organic conversion  horticultural land.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD8 Manage grassland to reduce nutrient levels in groundwater.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/GRH10 Lenient grazing supplement.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BFS5 Protect infield trees on intensive grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CHRW2 Manage hedgerows.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CMOR1 Assess moorland and produce a written record.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CIPM4 No use of insecticide on arable crops and permanent crops.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CLIG3 Manage grassland with very low nutrient inputs.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/BFS3 Buffer infield ponds on improved grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/AHW9 Unharvested cereal headland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/SOH2 Multispecies springsown cover crop.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL7 Shepherding livestock on moorland no required stock removal period.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD4 Arable reversion to grassland with low fertiliser input.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CIGL2 Winter bird food on improved grassland.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL9 Shepherding livestock on moorland remove stock for at least 6 months.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/WBD9 Nil fertiliser supplement.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL4 Keep cattle and ponies on moorland supplement minimum 30 GLU.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/UPL6 Keep cattle and ponies on moorland supplement 100 GLU.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/HEF5 Control scrub on historic and archaeological features.txt'
# Document saved as '/Users/joe/Documents/git/defra/ffc-rps-scratchpad/src/python/output/expanded_sections/txt/CHRW1 Assess and record hedgerow condition.txt'
